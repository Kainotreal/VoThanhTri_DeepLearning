# %%
from chefboost import Chefboost as chef
import pandas as pd
df=pd.read_csv("C:/DeepLearning/Lab1/iris.data")
df = df.sample(frac=1).reset_index(drop=True)
df.head()

print("ID3 algorithm\n")

#set algorithm
config = {'algorithm': 'ID3'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']  
    #print(actual,"-",prediction)
    
print("C4.5 algorithm\n")

#set algorithm
config = {'algorithm': 'C4.5'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    print(actual,"-",prediction)
    
print("CART algorithm\n")

#set algorithm
config = {'algorithm': 'CART'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    #print(actual,"-",prediction)
# Out:
# ID3 algorithm
#
# 26-03-06 16:05:20 - ID3 tree is going to be built...
# 26-03-06 16:05:22 - -------------------------
# 26-03-06 16:05:22 - finished in 1.2906913757324219 seconds
# 26-03-06 16:05:22 - -------------------------
# 26-03-06 16:05:22 - Evaluate train set
# 26-03-06 16:05:22 - -------------------------
# 26-03-06 16:05:22 - Accuracy: 99.0% on 100 instances
# 26-03-06 16:05:22 - Labels: ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa']
# 26-03-06 16:05:22 - Confusion matrix: [[32, 0, 0], [1, 35, 0], [0, 0, 32]]
# 26-03-06 16:05:22 - Decision Iris-virginica
# 26-03-06 16:05:22 - Accuracy: 99.0
# 26-03-06 16:05:22 - Precision: 100.0%, Recall: 96.9697%, F1: 98.4615%
# 26-03-06 16:05:22 - Decision Iris-versicolor
# 26-03-06 16:05:22 - Accuracy: 99.0
# 26-03-06 16:05:22 - Precision: 97.2222%, Recall: 100.0%, F1: 98.5915%
# 26-03-06 16:05:22 - Decision Iris-setosa
# 26-03-06 16:05:22 - Accuracy: 100.0
# 26-03-06 16:05:22 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# C4.5 algorithm
#
# 26-03-06 16:05:22 - C4.5 tree is going to be built...
# c:\DeepLearning\Lab1\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[2]>2.0744597382947285:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3]<=1.6:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0]<=7.0:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[1]<=2.7:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[1]>2.7:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3]>1.6:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0]>5.9:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0]<=5.9:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj
py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[2]>2.0744597382947285:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3]<=1.6:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0]<=7.0:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[1]<=2.7:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[1]>2.7:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3]>1.6:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0]>5.9:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0]<=5.9:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[1]<=3.0:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[2]<=2.0744597382947285:
# 26-03-06 16:05:24 - -------------------------
# 26-03-06 16:05:24 - finished in 1.3123443126678467 seconds
# 26-03-06 16:05:24 - -------------------------
# 26-03-06 16:05:24 - Evaluate train set
# 26-03-06 16:05:24 - -------------------------
# 26-03-06 16:05:24 - Accuracy: 99.0% on 100 instances
# 26-03-06 16:05:24 - Labels: ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa']
# 26-03-06 16:05:24 - Confusion matrix: [[32, 0, 0], [1, 35, 0], [0, 0, 32]]
# 26-03-06 16:05:24 - Decision Iris-virginica
# 26-03-06 16:05:24 - Accuracy: 99.0
# 26-03-06 16:05:24 - Precision: 100.0%, Recall: 96.9697%, F1: 98.4615%
# 26-03-06 16:05:24 - Decision Iris-versicolor
# 26-03-06 16:05:24 - Accuracy: 99.0
# 26-03-06 16:05:24 - Precision: 97.2222%, Recall: 100.0%, F1: 98.5915%
# 26-03-06 16:05:24 - Decision Iris-setosa
# 26-03-06 16:05:24 - Accuracy: 100.0
# 26-03-06 16:05:24 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# c:\DeepLearning\Lab1\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[2]>2.0744597382947285:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3]<=1.6:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0]<=7.0:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[1]<=2.7:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[1]>2.7:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3]>1.6:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0]>5.9:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0]<=5.9:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[1]<=3.0:
# c:\DeepLearning\Lab1\outputs\rules\rules.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[2]<=2.0744597382947285:
