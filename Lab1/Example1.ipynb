# %%
# Chefboost is available at: https://github.com/serengil/chefboost

from chefboost import Chefboost as chef
import pandas as pd

df = pd.read_csv("C:/DeepLearning/Lab1/golf.txt")
df.head()
# Out:
#     Outlook Temp. Humidity    Wind Decision
# 0     Sunny   Hot     High    Weak       No
# 1     Sunny   Hot     High  Strong       No
# 2  Overcast   Hot     High    Weak      Yes
# 3      Rain  Mild     High    Weak      Yes
# 4      Rain  Cool   Normal    Weak      Yes

# %%
print("ID3 algorithm\n")

#set algorithm
config = {'algorithm': 'ID3'}

#train model on training dataset
print("Train model on traing dataset:")
model = chef.fit(df[:8].copy(), config)

#define x vector for given day
xrow = ['Sunny','Hot','High','Weak']

#make prediction for given day
prediction = chef.predict(model, xrow)
print("Prediction for given day. Should we play? {0}".format(prediction))

c=0
print("\nCompare predictions and expected results on TESTING dataset:")
#prediction on testing data set
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']  
    print(actual,"-",prediction)
    if(actual==prediction):
        c=c+1
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# ID3 algorithm
#
# Train model on traing dataset:
# 26-03-06 15:55:09 - ID3 tree is going to be built...
# 26-03-06 15:55:10 - -------------------------
# 26-03-06 15:55:10 - finished in 0.37928104400634766 seconds
# 26-03-06 15:55:10 - -------------------------
# 26-03-06 15:55:10 - Evaluate train set
# 26-03-06 15:55:10 - -------------------------
# 26-03-06 15:55:10 - Accuracy: 100.0% on 8 instances
# 26-03-06 15:55:10 - Labels: ['No' 'Yes']
# 26-03-06 15:55:10 - Confusion matrix: [[4, 0], [0, 4]]
# 26-03-06 15:55:10 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# Prediction for given day. Should we play? No
#
# Compare predictions and expected results on TESTING dataset:
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
print("C4.5 algorithm\n")

#set algorithm
config = {'algorithm': 'C4.5'}
model = chef.fit(df[:8], config)

#define xrow
xrow  = ['Sunny','Hot','High','Weak']

#make single prediction
prediction = chef.predict(model,xrow)

#prediction on test data set
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    
    print(actual,"-",prediction)
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# C4.5 algorithm
#
# 26-03-06 15:56:44 - C4.5 tree is going to be built...
# 26-03-06 15:56:45 - -------------------------
# 26-03-06 15:56:45 - finished in 0.27709317207336426 seconds
# 26-03-06 15:56:45 - -------------------------
# 26-03-06 15:56:45 - Evaluate train set
# 26-03-06 15:56:45 - -------------------------
# 26-03-06 15:56:45 - Accuracy: 100.0% on 8 instances
# 26-03-06 15:56:45 - Labels: ['No' 'Yes']
# 26-03-06 15:56:45 - Confusion matrix: [[4, 0], [0, 4]]
# 26-03-06 15:56:45 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
print("CART algorithm\n")

#set algorithm
config = {'algorithm': 'CART'}
model = chef.fit(df[:8], config)

#define single x vector
xrow = ['Sunny','Hot','High','Weak']

#make single prediction
prediction = chef.predict(model, xrow)

#prediction on test data set
print("\nCompare predictions and expected results on TESTING dataset:")
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    
    print(actual,"-",prediction)
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# CART algorithm
#
# 26-03-06 15:56:57 - CART tree is going to be built...
# 26-03-06 15:56:57 - -------------------------
# 26-03-06 15:56:57 - finished in 0.4313631057739258 seconds
# 26-03-06 15:56:57 - -------------------------
# 26-03-06 15:56:57 - Evaluate train set
# 26-03-06 15:56:57 - -------------------------
# 26-03-06 15:56:57 - Accuracy: 100.0% on 8 instances
# 26-03-06 15:56:58 - Labels: ['No' 'Yes']
# 26-03-06 15:56:58 - Confusion matrix: [[4, 0], [0, 4]]
# 26-03-06 15:56:58 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
#
# Compare predictions and expected results on TESTING dataset:
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# C:\Users\ADMIN\Untitled Folder\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':
